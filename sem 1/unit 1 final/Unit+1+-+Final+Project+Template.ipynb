# %% [markdown]
# # Choose a Data Set
# Pick one of the following data sets to analyze for your final project.
# - [Cosmetics](https://drive.google.com/drive/folders/1qvmRfGb7a_pYAtgW6614gxlP-bxl_Ptz?usp=drive_link)
# - [Mental Health](https://drive.google.com/drive/folders/1YOp1aQVcmqlAkUEGHNPl_TyNXbY-xHwO?usp=drive_link)
# - [Pokemon](https://drive.google.com/drive/folders/1kDu2oRgm_hUW5hdM0tHnMUqCGSKUYT1v?usp=drive_link)
# - [Ramen](https://drive.google.com/drive/folders/1Y4_5QHOCy8rHc5EsEwDUuoCfp2WLo-MN?usp=drive_link)
# - [Student Performance](https://drive.google.com/drive/folders/1fE31Ka38AnGpgfI_Es3z4psuA0phhH0Y?usp=drive_link)

# %% [markdown]
# # My Question

# %% [markdown]
# what is the most popular style of ramen in each country?

# %% [markdown]
# # My Analysis

# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv("ramen.csv")
frequency_table = df['Style'].value_counts()
print(frequency_table)
# Out:
# Pack    1531
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: Style, dtype: int64

# %%
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
pack = df[df['Style'] == 'Pack']

country_counts = pack ['Country'].value_counts().nlargest(10).reset_index()
country_counts.columns = ['Country', 'Count']

sns.set(style="whitegrid")
bar_plot = sns.barplot(x='Country', y='Count', data=country_counts, palette="viridis")

bar_plot.set_xlabel('Country')
bar_plot.set_ylabel('Number of Packaged Ramen')
bar_plot.set_title('Top 10 Countries with the Most Packaged Ramen')
bar_plot.figure.set_size_inches(10, 6) 
bar_plot.figure.tight_layout()
bar_plot.figure.show()
# Out:
# C:\Users\bgraham\AppData\Local\Temp\ipykernel_14252\3383437931.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   bar_plot.figure.show()

# %%
north_korea_ramen = df[df['Country'] == 'North Korea']
style_counts = north_korea_ramen['Style'].value_counts()
relative_frequencies = style_counts / style_counts.sum()
print(relative_frequencies)
# Out:
# Series([], Name: Style, dtype: float64)

# %% [markdown]
# # My Answer

# %% [markdown]
# ***Write your answer here.***
