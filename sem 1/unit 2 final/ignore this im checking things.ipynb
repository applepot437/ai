# %%
import requests

url = "https://api.themoviedb.org/3/tv/airing_today?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIzZmUzNzFjZmYzMjljNWVlYWY0NjFiNzIxZjU2YWViZSIsIm5iZiI6MTcyNzk2OTE2NC43NDg5OTk4LCJzdWIiOiI2NmZlYjc4Y2M5YTEwZDQ2ZWE3YzliY2MiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.KGCHoyJHDrXcm4tJfNfhSRtou5dykH9BAYURAYMT7yU"
}

response = requests.get(url, headers=headers)
response = response.json()
now = pd.DataFrame(response["results"])
now.head()
# Out:
#    adult                     backdrop_path                      genre_ids  \
# 0  False  /lmvsFQpAhx4k9dqKvOgb2B63MsC.jpg                 [10763, 10767]
# 1  False  /vgeDRVpSUa4Hvovg4C6dgm4dfUW.jpg                    [10766, 18]
# 2  False  /zSPvARNCFpZxmWjgJCsBu5PUlR9.jpg  [35, 18, 10751, 10762, 10759]
# 3  False  /4i3iJepkqqH5JJgTNLJdi8ke6ir.jpg                        [10766]
# 4  False  /i8iqYtAy9qcO5RSrA1f6fY1n6SN.jpg                        [10766]
#
#        id origin_country original_language           original_name  \
# 0  113779           [DE]                de            Hallo Hessen
# 1  112470           [FR]                fr       Ici tout commence
# 2  247885       [MX, US]                en  Papás por Conveniencia
# 3  249010           [ZA]                af     Kelders van Geheime
# 4  235484           [ZA]                af              Suidooster
#
#                                             overview  popularity  \
# 0                                                       4066.418
# 1  This television drama series is centered aroun...    3399.044
# 2  Tino, a single father who faces great challeng...    3309.144
# 3  Kelders van Geheime (Cellars of Secrets) is a ...    3103.593
# 4  Suidooster is a South African television soap ...    3094.407
#
#                         poster_path first_air_date                    name  \
# 0  /zRGme9GL0H5RmwzxKYzoXafcRDp.jpg     2012-01-30            Hallo Hessen
# 1  /yuTHx38jpogXovMhqNatvozigMJ.jpg     2020-11-02       Ici tout commence
# 2  /y7yIu9PKx2WTphhYgbBq9C1RNzV.jpg     2024-10-21  Papás por Conveniencia
# 3  /vf1I0G5jICTstI1EXxb9Oqq80TU.jpg     2024-05-06     Kelders van Geheime
# 4  /naCgSiacvV685kait6fBvhVhdce.jpg     2015-11-16              Suidooster
#
#    vote_average  vote_count
# 0           7.0           2
# 1           7.0          77
# 2           7.8          25
# 3           6.2          10
# 4           7.8          19
